# %% [markdown]
# Running AlphaFold2 (from ColabFold) using Azure Machine Learning
# Notebook is similar to Colby T. Ford, Ph.D. (https://github.com/colbyford/azureml-alphafold2)

# %%
import numpy as np
import pandas as pd
from azureml.core import Workspace, Dataset, Run

ws = Workspace.from_config()

# %% [markdown]
# #Target computation

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "alphafold2-ic"

try:
    ## Check for existing compute target
    training_cluster = ComputeTarget(workspace = ws, name = cluster_name)
    print('Found existing cluster.')
except ComputeTargetException:
    ## If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size = 'STANDARD_NC6', max_nodes = 4)
        training_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        training_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster.

# %% [markdown]
# #Configure HyperDrive

# %%
from azureml.core import Experiment, ScriptRunConfig, Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.train.hyperdrive import GridParameterSampling, RandomParameterSampling, HyperDriveConfig, PrimaryMetricGoal, choice
from azureml.widgets import RunDetails

# Create a Python environment for the experiment
alphafold2_env = Environment("alphafold2")
alphafold2_env.docker.base_image = "cford38/alphafold2_aml:latest"
alphafold2_env.python.user_managed_dependencies = True

## Create a script config
script_config = ScriptRunConfig(source_directory = ".",
                                script='predict.py',
                                arguments = ['--msa_mode', "MMseqs2 (UniRef+Environmental)",
                                             '--num_models', 1,
                                             '--num_recycles', 3,
                                            '--stop_at_score', 90],
                                environment = alphafold2_env,
                                compute_target = training_cluster)

## Sample a range of parameter values
params = GridParameterSampling({ '--sequence_id': choice('alpha_b117_6xc2', 'beta_b1351_7vx1', 'delta_b1617_7v70', 'omicron_b11529_7t9j') })

## Configure hyperdrive settings
hyperdrive = HyperDriveConfig(run_config = script_config, 
                              hyperparameter_sampling = params, 
                              policy = None, 
                              primary_metric_name = 'complete', 
                              primary_metric_goal = PrimaryMetricGoal.MAXIMIZE, 
                              max_total_runs = 4,
                              max_concurrent_runs = 4)

# %% [markdown]
# Define Prediction Script

# %%
# %%writefile predict.py
## Import libraries
import argparse, joblib, os, sys
from azureml.core import Dataset, Run
import pandas as pd
import numpy as np

from colabfold.batch import get_queries
from colabfold.batch import run as foldrun
from colabfold.download import default_data_dir
from colabfold.utils import setup_logging
from pathlib import Path
from Bio import SeqIO

os.makedirs('outputs', exist_ok=True)

## Set the input parameters
parser = argparse.ArgumentParser()
parser.add_argument("--sequence_id", type=str, dest='sequence_id', help='Input Sequence ID')
parser.add_argument("--msa_mode", type=str, dest='msa_mode', help='msa mode')
parser.add_argument("--num_models", type=int, dest='num_models', help='number of structures to predict')
parser.add_argument("--num_recycles", type=int, dest='num_recycles', help='number of recycles')
parser.add_argument("--stop_at_score", type=int, dest='stop_at_score', help='early stop after reaching this p1DDT score.')

args = parser.parse_args()

## Get the experiment run context
run = Run.get_context()
ws = run.experiment.workspace

## Settings
# msa_mode = "MMseqs2 (UniRef+Environmental)" #["MMseqs2 (UniRef+Environmental)", "MMseqs2 (UniRef only)","single_sequence","custom"]
# num_models = 1
# num_recycles = 3
# stop_at_score = 90

sequence_id = args.sequence_id
msa_mode = args.msa_mode
num_models = args.num_models
num_recycles = args.num_recycles
stop_at_score = args.stop_at_score

use_custom_msa = False
use_amber = False
use_templates = False 
do_not_overwrite_results = False
zip_results = False

## Log run options
run.log('sequence_id', str(sequence_id))
run.log('msa_mode', str(msa_mode))
run.log('num_models', str(num_models))
run.log('num_recycles', str(num_recycles))
run.log('stop_at_score', str(stop_at_score))

## load the sequence(s)
print("Loading sequences...")

for record in SeqIO.parse("sequences.fasta", "fasta"):
    if sequence_id == record.description:
        ## Write out the specific sequence fasta file for this node
        SeqIO.write(record, open("run_sequence.fasta", "w"), "fasta")

## Output and Input directories
result_dir = 'outputs/predicted_structures/'
input_dir = 'run_sequence.fasta'

## Set up Logging
setup_logging(Path(result_dir).joinpath("log.txt"))
## Set up query tasks (1 per input sequence)
queries, is_complex = get_queries(input_dir)

## Run Fold Prediction
foldrun(
    queries=queries,
    result_dir=result_dir,
    use_templates=use_templates,
    use_amber=use_amber,
    msa_mode=msa_mode,
    model_type="auto",
    num_models=num_models,
    num_recycles=num_recycles,
    model_order=[1],
    is_complex=is_complex,
    data_dir=default_data_dir,
    keep_existing_results=do_not_overwrite_results,
    rank_by="auto",
    pair_mode="unpaired+paired",
    stop_at_score=stop_at_score,
    zip_results=zip_results,
)

run.log('complete', np.int(1))

run.complete()
# Out:
# Overwriting predict.py

# %% [markdown]
# Submit the HyperDrive Experiment

# %%
experiment = Experiment(workspace = ws, name = 'alphafold2_hyperdrive')
run = experiment.submit(config = hyperdrive)

## Show the status in the notebook as the experiment runs
RunDetails(run).show()
run.wait_for_completion()
# Out:
# _HyperDriveWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO'…
# Performing interactive authentication. Please follow the instructions on the terminal.
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/urllib3/connection.py:159, in HTTPConnection._new_conn(self)
#     158 try:
# --> 159     conn = connection.create_connection(
#     160         (self._dns_host, self.port), self.timeout, **extra_kw
#     161     )
#     163 except SocketTimeout:
#
# File /usr/lib/python3/dist-packages/urllib3/util/connection.py:61, in create_connection(address, timeout, source_address, socket_options)
#      59 family = allowed_gai_family()
# ---> 61 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62     af, socktype, proto, canonname, sa = res
#
# File /usr/lib/python3.8/socket.py:918, in getaddrinfo(host, port, family, type, proto, flags)
#     917 addrlist = []
# --> 918 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:665, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     664 # Make the request on the httplib connection object.
# --> 665 httplib_response = self._make_request(
#     666     conn,
#     667     method,
#     668     url,
#     669     timeout=timeout_obj,
#     670     body=body,
#     671     headers=headers,
#     672     chunked=chunked,
#     673 )
#     675 # If we're going to release the connection in ``finally:``, then
#     676 # the response doesn't need to know about the connection. Otherwise
#     677 # it will also try to release it and we'll have a double-release
#     678 # mess.
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:376, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375 try:
# --> 376     self._validate_conn(conn)
#     377 except (SocketTimeout, BaseSSLError) as e:
#     378     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:996, in HTTPSConnectionPool._validate_conn(self, conn)
#     995 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 996     conn.connect()
#     998 if not conn.is_verified:
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:314, in VerifiedHTTPSConnection.connect(self)
#     312 def connect(self):
#     313     # Add certificate verification
# --> 314     conn = self._new_conn()
#     315     hostname = self.host
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:171, in HTTPConnection._new_conn(self)
#     170 except SocketError as e:
# --> 171     raise NewConnectionError(
#     172         self, "Failed to establish a new connection: %s" % e
#     173     )
#     175 return conn
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x7f6cf4b87df0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 if not chunked:
# --> 439     resp = conn.urlopen(
#     440         method=request.method,
#     441         url=url,
#     442         body=request.body,
#     443         headers=request.headers,
#     444         redirect=False,
#     445         assert_same_host=False,
#     446         preload_content=False,
#     447         decode_content=False,
#     448         retries=self.max_retries,
#     449         timeout=timeout
#     450     )
#     452 # Send the request.
#     453 else:
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:747, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     744     log.warning(
#     745         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     746     )
# --> 747     return self.urlopen(
#     748         method,
#     749         url,
#     750         body,
#     751         headers,
#     752         retries,
#     753         redirect,
#     754         assert_same_host,
#     755         timeout=timeout,
#     756         pool_timeout=pool_timeout,
#     757         release_conn=release_conn,
#     758         chunked=chunked,
#     759         body_pos=body_pos,
#     760         **response_kw
#     761     )
#     763 def drain_and_release_conn(response):
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:719, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     717     e = ProtocolError("Connection aborted.", e)
# --> 719 retries = retries.increment(
#     720     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721 )
#     722 retries.sleep()
#
# File /usr/lib/python3/dist-packages/urllib3/util/retry.py:436, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     435 if new_retry.is_exhausted():
# --> 436     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     438 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='login.microsoftonline.com', port=443): Max retries exceeded with url: /22b5f01a-73c1-4d73-bfa9-7fb2ac0dd5fe/v2.0/.well-known/openid-configuration (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f6cf4b87df0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/azureml/core/authentication.py:2283, in _get_arm_token_with_refresh(profile_object, cloud_type, account_object, config_object, session_object, config_directory, force_reload, resource, use_adal_auth)
#    2280 try:
#    2281     # profile_object.get_raw_token is being used as per the suggestion
#    2282     # https://github.com/Azure/azure-cli/issues/15805#issuecomment-722914070
# -> 2283     access_token = profile_object.get_raw_token(resource=resource)[0][1]
#    2284     """
#    2285     According to below documentation, MSAL takes care of refreshing old tokens. In that case, we do not
#    2286     need to explicitly test and check for token expiry, making below code redundant.
#    (...)
#    2289
#    2290     """
#
# File ~/.local/lib/python3.8/site-packages/azureml/_vendor/azure_cli_core/_profile.py:381, in Profile.get_raw_token(self, resource, scopes, subscription, tenant)
#     380 else:
# --> 381     credential = self._create_credential(account, tenant)
#     382     token = credential.get_token(*scopes)
#
# File ~/.local/lib/python3.8/site-packages/azureml/_vendor/azure_cli_core/_profile.py:588, in Profile._create_credential(self, account, tenant_id, client_id)
#     587 if user_type == _USER:
# --> 588     return identity.get_user_credential(username_or_sp_id)
#     590 # Service Principal
#
# File ~/.local/lib/python3.8/site-packages/azureml/_vendor/azure_cli_core/auth/identity.py:182, in Identity.get_user_credential(self, username)
#     181 def get_user_credential(self, username):
# --> 182     return UserCredential(self.client_id, username, **self._msal_app_kwargs)
#
# File ~/.local/lib/python3.8/site-packages/azureml/_vendor/azure_cli_core/auth/msal_authentication.py:38, in UserCredential.__init__(self, client_id, username, **kwargs)
#      33 """User credential implementing get_token interface.
#      34
#      35 :param client_id: Client ID of the CLI.
#      36 :param username: The username for user credential.
#      37 """
# ---> 38 super().__init__(client_id, **kwargs)
#      40 accounts = self.get_accounts(username)
#
# File ~/.local/lib/python3.8/site-packages/msal/application.py:1466, in PublicClientApplication.__init__(self, client_id, client_credential, **kwargs)
#    1465     raise ValueError("Public Client should not possess credentials")
# -> 1466 super(PublicClientApplication, self).__init__(
#    1467     client_id, client_credential=None, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/msal/application.py:438, in ClientApplication.__init__(self, client_id, client_credential, authority, validate_authority, token_cache, http_client, verify, proxies, timeout, client_claims, app_name, app_version, client_capabilities, azure_region, exclude_scopes, http_cache)
#     437 try:
# --> 438     self.authority = Authority(
#     439         authority or "https://login.microsoftonline.com/common/",
#     440         self.http_client, validate_authority=validate_authority)
#     441 except ValueError:  # Those are explicit authority validation errors
#
# File ~/.local/lib/python3.8/site-packages/msal/authority.py:83, in Authority.__init__(self, authority_url, http_client, validate_authority)
#      82 try:
# ---> 83     openid_config = tenant_discovery(
#      84         tenant_discovery_endpoint,
#      85         self.http_client)
#      86 except ValueError:
#
# File ~/.local/lib/python3.8/site-packages/msal/authority.py:142, in tenant_discovery(tenant_discovery_endpoint, http_client, **kwargs)
#     140 def tenant_discovery(tenant_discovery_endpoint, http_client, **kwargs):
#     141     # Returns Openid Configuration
# --> 142     resp = http_client.get(tenant_discovery_endpoint, **kwargs)
#     143     if resp.status_code == 200:
#
# File ~/.local/lib/python3.8/site-packages/msal/individual_cache.py:269, in _IndividualCache.__call__.<locals>.wrapper(*args, **kwargs)
#     268     pass
# --> 269 value = function(*args, **kwargs)
#     271 expires_in = self._expires_in(
#     272     function=function,
#     273     args=args,
#     274     kwargs=kwargs,
#     275     result=value,
#     276     ) if callable(self._expires_in) else self._expires_in
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:546, in Session.get(self, url, **kwargs)
#     545 kwargs.setdefault('allow_redirects', True)
# --> 546 return self.request('GET', url, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:533, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     532 send_kwargs.update(settings)
# --> 533 resp = self.send(prep, **send_kwargs)
#     535 return resp
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:646, in Session.send(self, request, **kwargs)
#     645 # Send the request
# --> 646 r = adapter.send(request, **kwargs)
#     648 # Total elapsed time of the request (approximately)
#
# File /usr/lib/python3/dist-packages/requests/adapters.py:516, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     514         raise SSLError(e, request=request)
# --> 516     raise ConnectionError(e, request=request)
#     518 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='login.microsoftonline.com', port=443): Max retries exceeded with url: /22b5f01a-73c1-4d73-bfa9-7fb2ac0dd5fe/v2.0/.well-known/openid-configuration (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f6cf4b87df0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationException                   Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/azureml/core/authentication.py:389, in _login_on_failure_decorator.<locals>.actual_decorator.<locals>.wrapper(self, *args, **kwargs)
#     388         module_logger.debug("{} acquired lock in {} s.".format(type(self).__name__, duration))
# --> 389     return test_function(self, *args, **kwargs)
#     390 except Exception as e:
#
# File ~/.local/lib/python3.8/site-packages/azureml/core/authentication.py:606, in InteractiveLoginAuthentication._get_arm_token(self)
#     605 else:
# --> 606     return self._get_arm_token_using_interactive_auth()
#
# File ~/.local/lib/python3.8/site-packages/azureml/core/authentication.py:748, in InteractiveLoginAuthentication._get_arm_token_using_interactive_auth(self, force_reload, resource)
#     747 # If we can get a valid ARM token, then we don't need to login.
# --> 748 arm_token = _get_arm_token_with_refresh(
#     749     profile_object, cloud_type, ACCOUNT, CONFIG, SESSION, get_config_dir(), force_reload=force_reload,
#     750     resource=resource, use_adal_auth=self._use_adal_auth
#     751 )
#     752 # If a user has specified a tenant id then we need to check if this token is for that tenant.
#
# File ~/.local/lib/python3.8/site-packages/azureml/core/authentication.py:426, in _retry_connection_aborted.<locals>.actual_decorator.<locals>.connection_aborted_wrapper(*args, **kwargs)
#     425 try:
# --> 426     return function(*args, **kwargs)
#     427 except AuthenticationException as e:
#
# File ~/.local/lib/python3.8/site-packages/azureml/core/authentication.py:2293, in _get_arm_token_with_refresh(profile_object, cloud_type, account_object, config_object, session_object, config_directory, force_reload, resource, use_adal_auth)
#    2292     except Exception as e:
# -> 2293         raise AuthenticationException("Could not retrieve user token. Please run 'az login'", inner_exception=e)
#    2294 else:
#    2295     # From notebook, we want to persist tokens synchronously to the on-disk file,
#    2296     # so that users don't have to run az login multiple times.
#    (...)
#    2299     # is not called.
#    2300     # profile = Profile(async_persist=False)
#
# AuthenticationException: AuthenticationException:
# 	Message: Could not retrieve user token. Please run 'az login'
# 	InnerException HTTPSConnectionPool(host='login.microsoftonline.com', port=443): Max retries exceeded with url: /22b5f01a-73c1-4d73-bfa9-7fb2ac0dd5fe/v2.0/.well-known/openid-configuration (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f6cf4b87df0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
# 	ErrorResponse
# {
#     "error": {
#         "code": "UserError",
#         "inner_error": {
#             "code": "Authentication"
#         },
#         "message": "Could not retrieve user token. Please run 'az login'"
#     }
# }
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/urllib3/connection.py:159, in HTTPConnection._new_conn(self)
#     158 try:
# --> 159     conn = connection.create_connection(
#     160         (self._dns_host, self.port), self.timeout, **extra_kw
#     161     )
#     163 except SocketTimeout:
#
# File /usr/lib/python3/dist-packages/urllib3/util/connection.py:61, in create_connection(address, timeout, source_address, socket_options)
#      59 family = allowed_gai_family()
# ---> 61 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62     af, socktype, proto, canonname, sa = res
#
# File /usr/lib/python3.8/socket.py:918, in getaddrinfo(host, port, family, type, proto, flags)
#     917 addrlist = []
# --> 918 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:665, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     664 # Make the request on the httplib connection object.
# --> 665 httplib_response = self._make_request(
#     666     conn,
#     667     method,
#     668     url,
#     669     timeout=timeout_obj,
#     670     body=body,
#     671     headers=headers,
#     672     chunked=chunked,
#     673 )
#     675 # If we're going to release the connection in ``finally:``, then
#     676 # the response doesn't need to know about the connection. Otherwise
#     677 # it will also try to release it and we'll have a double-release
#     678 # mess.
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:376, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375 try:
# --> 376     self._validate_conn(conn)
#     377 except (SocketTimeout, BaseSSLError) as e:
#     378     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:996, in HTTPSConnectionPool._validate_conn(self, conn)
#     995 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 996     conn.connect()
#     998 if not conn.is_verified:
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:314, in VerifiedHTTPSConnection.connect(self)
#     312 def connect(self):
#     313     # Add certificate verification
# --> 314     conn = self._new_conn()
#     315     hostname = self.host
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:171, in HTTPConnection._new_conn(self)
#     170 except SocketError as e:
# --> 171     raise NewConnectionError(
#     172         self, "Failed to establish a new connection: %s" % e
#     173     )
#     175 return conn
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x7f6cc0774280>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 if not chunked:
# --> 439     resp = conn.urlopen(
#     440         method=request.method,
#     441         url=url,
#     442         body=request.body,
#     443         headers=request.headers,
#     444         redirect=False,
#     445         assert_same_host=False,
#     446         preload_content=False,
#     447         decode_content=False,
#     448         retries=self.max_retries,
#     449         timeout=timeout
#     450     )
#     452 # Send the request.
#     453 else:
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:747, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     744     log.warning(
#     745         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     746     )
# --> 747     return self.urlopen(
#     748         method,
#     749         url,
#     750         body,
#     751         headers,
#     752         retries,
#     753         redirect,
#     754         assert_same_host,
#     755         timeout=timeout,
#     756         pool_timeout=pool_timeout,
#     757         release_conn=release_conn,
#     758         chunked=chunked,
#     759         body_pos=body_pos,
#     760         **response_kw
#     761     )
#     763 def drain_and_release_conn(response):
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:719, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     717     e = ProtocolError("Connection aborted.", e)
# --> 719 retries = retries.increment(
#     720     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721 )
#     722 retries.sleep()
#
# File /usr/lib/python3/dist-packages/urllib3/util/retry.py:436, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     435 if new_retry.is_exhausted():
# --> 436     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     438 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='login.microsoftonline.com', port=443): Max retries exceeded with url: /organizations/v2.0/.well-known/openid-configuration (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f6cc0774280>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/azureml/_base_sdk_common/common.py:573, in perform_interactive_login(username, password, service_principal, tenant, allow_no_subscriptions, identity, use_device_code, use_cert_sn_issuer, cloud_type)
#     572 try:
# --> 573     subscriptions = profile.login(
#     574         interactive,
#     575         username,
#     576         credential,
#     577         service_principal,
#     578         tenant,
#     579         use_device_code=use_device_code,
#     580         allow_no_subscriptions=allow_no_subscriptions,
#     581         use_cert_sn_issuer=use_cert_sn_issuer)
#     582 except MsalError as err:
#     583     # try polish unfriendly server errors
#
# File ~/.local/lib/python3.8/site-packages/azureml/_vendor/azure_cli_core/_profile.py:155, in Profile.login(self, interactive, username, password, is_service_principal, tenant, scopes, use_device_code, allow_no_subscriptions, use_cert_sn_issuer, **kwargs)
#     154     else:
# --> 155         user_identity = identity.login_with_auth_code(scopes=scopes, **kwargs)
#     156 else:
#
# File ~/.local/lib/python3.8/site-packages/azureml/_vendor/azure_cli_core/auth/identity.py:114, in Identity.login_with_auth_code(self, scopes, **kwargs)
#     109 def login_with_auth_code(self, scopes, **kwargs):
#     110     # Emit a warning to inform that a browser is opened.
#     111     # Only show the path part of the URL and hide the query string.
#     112     logger.warning("The default web browser has been opened at %s. Please continue the login in the web browser. "
#     113                    "If no web browser is available or if the web browser fails to open, use device code flow "
# --> 114                    "with `az login --use-device-code`.", self.msal_app.authority.authorization_endpoint)
#     116     from .util import read_response_templates
#
# File ~/.local/lib/python3.8/site-packages/azureml/_vendor/azure_cli_core/auth/identity.py:106, in Identity.msal_app(self)
#     105 if not self._msal_app_instance:
# --> 106     self._msal_app_instance = self._build_persistent_msal_app()
#     107 return self._msal_app_instance
#
# File ~/.local/lib/python3.8/site-packages/azureml/_vendor/azure_cli_core/auth/identity.py:100, in Identity._build_persistent_msal_app(self)
#      98 def _build_persistent_msal_app(self):
#      99     # Initialize _msal_app for login and logout
# --> 100     msal_app = PublicClientApplication(self.client_id, **self._msal_app_kwargs)
#     101     return msal_app
#
# File ~/.local/lib/python3.8/site-packages/msal/application.py:1466, in PublicClientApplication.__init__(self, client_id, client_credential, **kwargs)
#    1465     raise ValueError("Public Client should not possess credentials")
# -> 1466 super(PublicClientApplication, self).__init__(
#    1467     client_id, client_credential=None, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/msal/application.py:438, in ClientApplication.__init__(self, client_id, client_credential, authority, validate_authority, token_cache, http_client, verify, proxies, timeout, client_claims, app_name, app_version, client_capabilities, azure_region, exclude_scopes, http_cache)
#     437 try:
# --> 438     self.authority = Authority(
#     439         authority or "https://login.microsoftonline.com/common/",
#     440         self.http_client, validate_authority=validate_authority)
#     441 except ValueError:  # Those are explicit authority validation errors
#
# File ~/.local/lib/python3.8/site-packages/msal/authority.py:83, in Authority.__init__(self, authority_url, http_client, validate_authority)
#      82 try:
# ---> 83     openid_config = tenant_discovery(
#      84         tenant_discovery_endpoint,
#      85         self.http_client)
#      86 except ValueError:
#
# File ~/.local/lib/python3.8/site-packages/msal/authority.py:142, in tenant_discovery(tenant_discovery_endpoint, http_client, **kwargs)
#     140 def tenant_discovery(tenant_discovery_endpoint, http_client, **kwargs):
#     141     # Returns Openid Configuration
# --> 142     resp = http_client.get(tenant_discovery_endpoint, **kwargs)
#     143     if resp.status_code == 200:
#
# File ~/.local/lib/python3.8/site-packages/msal/individual_cache.py:269, in _IndividualCache.__call__.<locals>.wrapper(*args, **kwargs)
#     268     pass
# --> 269 value = function(*args, **kwargs)
#     271 expires_in = self._expires_in(
#     272     function=function,
#     273     args=args,
#     274     kwargs=kwargs,
#     275     result=value,
#     276     ) if callable(self._expires_in) else self._expires_in
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:546, in Session.get(self, url, **kwargs)
#     545 kwargs.setdefault('allow_redirects', True)
# --> 546 return self.request('GET', url, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:533, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     532 send_kwargs.update(settings)
# --> 533 resp = self.send(prep, **send_kwargs)
#     535 return resp
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:646, in Session.send(self, request, **kwargs)
#     645 # Send the request
# --> 646 r = adapter.send(request, **kwargs)
#     648 # Total elapsed time of the request (approximately)
#
# File /usr/lib/python3/dist-packages/requests/adapters.py:516, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     514         raise SSLError(e, request=request)
# --> 516     raise ConnectionError(e, request=request)
#     518 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='login.microsoftonline.com', port=443): Max retries exceeded with url: /organizations/v2.0/.well-known/openid-configuration (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f6cc0774280>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationException                   Traceback (most recent call last)
# Input In [7], in <module>
#       4 ## Show the status in the notebook as the experiment runs
#       5 RunDetails(run).show()
# ----> 6 run.wait_for_completion()
#
# File ~/.local/lib/python3.8/site-packages/azureml/core/run.py:862, in Run.wait_for_completion(self, show_output, wait_post_processing, raise_on_error)
#     860 while current_status is None or current_status in running_states:
#     861     time.sleep(Run._wait_before_polling(time.time() - poll_start_time))
# --> 862     current_status = self.get_status()
#     863     # add unknown status as running status
#     864     if current_status not in RunStatus.list():
#
# File ~/.local/lib/python3.8/site-packages/azureml/core/run.py:1126, in Run.get_status(self)
#    1092 """Fetch the latest status of the run.
#    1093
#    1094 Common values returned include "Running", "Completed", and "Failed".
#    (...)
#    1123 :rtype: str
#    1124 """
#    1125 if self.status not in ["Completed", "Failed", "Canceled"]:
# -> 1126     self._client.refresh_run_dto()
#    1127 return self.status
#
# File ~/.local/lib/python3.8/site-packages/azureml/_run_impl/run_history_facade.py:191, in RunHistoryFacade.refresh_run_dto(self)
#     190 def refresh_run_dto(self):
# --> 191     self.run_dto = self.run.get_run()
#
# File ~/.local/lib/python3.8/site-packages/azureml/_restclient/run_client.py:78, in RunClient.get_run(self, **kwargs)
#      72 def get_run(self, **kwargs):
#      73     """
#      74     Get detail of a run by its run_id
#      75     This function could also be called from the super class,
#      76     ExperimentClient, for a specific run_id
#      77     """
# ---> 78     return super(RunClient, self).get_run(self._run_id, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/azureml/_restclient/experiment_client.py:129, in ExperimentClient.get_run(self, run_id, caller, custom_headers, is_async)
#     125 if self._experiment_id:
#     126     return self._execute_with_experimentid_arguments(self._client.run.get_by_exp_id,
#     127                                                      run_id=run_id,
#     128                                                      **kwargs)
# --> 129 return self._execute_with_experiment_arguments(self._client.run.get,
#     130                                                run_id=run_id,
#     131                                                **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/azureml/_restclient/experiment_client.py:260, in ExperimentClient._execute_with_experiment_arguments(self, func, *args, **kwargs)
#     259 def _execute_with_experiment_arguments(self, func, *args, **kwargs):
# --> 260     return self._execute_with_arguments(func, copy.deepcopy(self._experiment_arguments), *args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/azureml/_restclient/clientbase.py:589, in ClientBase._execute_with_arguments(self, func, args_list, *args, **kwargs)
#     587         return self._call_paginated_api(func, *args_list, **kwargs)
#     588     else:
# --> 589         return self._call_api(func, *args_list, **kwargs)
#     590 except ErrorResponseException as e:
#     591     raise ServiceException(e)
#
# File ~/.local/lib/python3.8/site-packages/azureml/_restclient/clientbase.py:245, in ClientBase._call_api(self, func, *args, **kwargs)
#     243     return AsyncTask(future, _ident=ident, _parent_logger=self._logger)
#     244 else:
# --> 245     return self._execute_with_base_arguments(func, *args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/azureml/_restclient/clientbase.py:333, in ClientBase._execute_with_base_arguments(self, func, *args, **kwargs)
#     331 back_off = self.backoff_factor
#     332 total_retry = 0 if self.retries < 0 else self.retries
# --> 333 return ClientBase._execute_func_internal(
#     334     back_off, total_retry, self._logger, func, _noop_reset, *args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/azureml/_restclient/clientbase.py:367, in ClientBase._execute_func_internal(cls, back_off, total_retry, logger, func, reset_func, *args, **kwargs)
#     365     return response
#     366 except Exception as error:
# --> 367     left_retry = cls._handle_retry(back_off, left_retry, total_retry, error, logger, func)
#     369 reset_func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/azureml/_restclient/clientbase.py:433, in ClientBase._handle_retry(cls, back_off, left_retry, total_retry, error, logger, func)
#     429         raise error
#     430 elif not isinstance(error, RETRY_EXCEPTIONS):
#     431     # the case 4 will be handled here by adding ConnectTime in the RETRY_EXCEPTIONS.
#     432     # also cover case 5
# --> 433     raise error
#     435 delay = cls._get_retry_delay(back_off, total_retry, left_retry, status_code)
#     437 left_retry -= 1
#
# File ~/.local/lib/python3.8/site-packages/azureml/_restclient/clientbase.py:358, in ClientBase._execute_func_internal(cls, back_off, total_retry, logger, func, reset_func, *args, **kwargs)
#     356 try:
#     357     logger.debug("ClientBase: Calling {} with url {}".format(func_name, func_url))
# --> 358     response = func(*args, **kwargs)
#     359     if (isinstance(response, Response) and cls._is_retryable_status_code(response.status_code) and
#     360             left_retry > 0):
#     361         # This is the handle the error case 1. response.raise_for_status only throws HTTPError exception.
#     362         # if the status_code is retryable and it is not the last retry, then the exception is thrown.
#     363         # Otherwise, we will return the response directly.
#     364         response.raise_for_status()
#
# File ~/.local/lib/python3.8/site-packages/azureml/_restclient/operations/run_operations.py:364, in RunOperations.get(self, subscription_id, resource_group_name, workspace_name, experiment_name, run_id, custom_headers, raw, **operation_config)
#     362 # Construct and send request
#     363 request = self._client.get(url, query_parameters)
# --> 364 response = self._client.send(request, header_parameters, stream=False, **operation_config)
#     366 if response.status_code not in [200]:
#     367     raise models.ErrorResponseException(self._deserialize, response)
#
# File ~/.local/lib/python3.8/site-packages/msrest/service_client.py:336, in ServiceClient.send(self, request, headers, content, **kwargs)
#     334 kwargs.setdefault('stream', True)
#     335 try:
# --> 336     pipeline_response = self.config.pipeline.run(request, **kwargs)
#     337     # There is too much thing that expects this method to return a "requests.Response"
#     338     # to break it in a compatible release.
#     339     # Also, to be pragmatic in the "sync" world "requests" rules anyway.
#     340     # However, attach the Universal HTTP response
#     341     # to get the streaming generator.
#     342     response = pipeline_response.http_response.internal_response
#
# File ~/.local/lib/python3.8/site-packages/msrest/pipeline/__init__.py:197, in Pipeline.run(self, request, **kwargs)
#     195 pipeline_request = Request(request, context)  # type: Request[HTTPRequestType]
#     196 first_node = self._impl_policies[0] if self._impl_policies else self._sender
# --> 197 return first_node.send(pipeline_request, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/msrest/pipeline/__init__.py:150, in _SansIOHTTPPolicyRunner.send(self, request, **kwargs)
#     148 self._policy.on_request(request, **kwargs)
#     149 try:
# --> 150     response = self.next.send(request, **kwargs)
#     151 except Exception:
#     152     if not self._policy.on_exception(request, **kwargs):
#
# File ~/.local/lib/python3.8/site-packages/msrest/pipeline/requests.py:65, in RequestsCredentialsPolicy.send(self, request, **kwargs)
#      63 session = request.context.session
#      64 try:
# ---> 65     self._creds.signed_session(session)
#      66 except TypeError: # Credentials does not support session injection
#      67     _LOGGER.warning("Your credentials class does not support session injection. Performance will not be at the maximum.")
#
# File ~/.local/lib/python3.8/site-packages/azureml/core/authentication.py:250, in AbstractAuthentication.signed_session(self, session)
#     239 """Add the authorization header as a persisted header on an HTTP session.
#     240
#     241 Any new requests sent by the session will contain the authorization header.
#    (...)
#     247 :rtype: requests.sessions.Session
#     248 """
#     249 session = session or Session()
# --> 250 session.headers.update(self.get_authentication_header())
#     251 return session
#
# File ~/.local/lib/python3.8/site-packages/azureml/core/authentication.py:127, in AbstractAuthentication.get_authentication_header(self)
#     117 """Return the HTTP authorization header.
#     118
#     119 The authorization header contains the user access token for access authorization against the service.
#    (...)
#     123 :rtype: dict
#     124 """
#     125 # We return a new dictionary each time, as some functions modify the headers returned
#     126 # by this function.
# --> 127 auth_header = {"Authorization": "Bearer " + self._get_arm_token()}
#     128 return auth_header
#
# File ~/.local/lib/python3.8/site-packages/azureml/core/authentication.py:393, in _login_on_failure_decorator.<locals>.actual_decorator.<locals>.wrapper(self, *args, **kwargs)
#     390 except Exception as e:
#     391     if type(self) == InteractiveLoginAuthentication:
#     392         # Perform InteractiveLoginAuthentication and try one more time.
# --> 393         InteractiveLoginAuthentication(force=True, tenant_id=self._tenant_id)
#     394         # Try one more time
#     395         return test_function(self, *args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/azureml/core/authentication.py:562, in InteractiveLoginAuthentication.__init__(self, force, tenant_id, cloud)
#     559 if force:
#     560     print("Performing interactive authentication. Please follow the instructions "
#     561           "on the terminal.")
# --> 562     perform_interactive_login(tenant=tenant_id, cloud_type=self._cloud_type)
#     563     print("Interactive authentication successfully completed.")
#     564 else:
#
# File ~/.local/lib/python3.8/site-packages/azureml/_base_sdk_common/common.py:593, in perform_interactive_login(username, password, service_principal, tenant, allow_no_subscriptions, identity, use_device_code, use_cert_sn_issuer, cloud_type)
#     591     raise AuthenticationException('Unknown error occurred during authentication. Error detail: ' + str(err))
#     592 except requests.exceptions.ConnectionError as err:
# --> 593     raise AuthenticationException('Please ensure you have network connection. Error detail: ' + str(err))
#     594 all_subscriptions = list(subscriptions)
#     595 for sub in all_subscriptions:
#
# AuthenticationException: AuthenticationException:
# 	Message: Please ensure you have network connection. Error detail: HTTPSConnectionPool(host='login.microsoftonline.com', port=443): Max retries exceeded with url: /organizations/v2.0/.well-known/openid-configuration (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f6cc0774280>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "code": "UserError",
#         "inner_error": {
#             "code": "Authentication"
#         },
#         "message": "Please ensure you have network connection. Error detail: HTTPSConnectionPool(host='login.microsoftonline.com', port=443): Max retries exceeded with url: /organizations/v2.0/.well-known/openid-configuration (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f6cc0774280>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))"
#     }
# }

# %% [markdown]
# Collect all the Results

# %%
import os

os.makedirs('./results', exist_ok = True)

## Get all child runs
parent_runid = run.id
child_runs = Run.get(ws, parent_runid).get_children(recursive = True)

## For each child run, download the outputs
for child in child_runs:
    child_runid = child.get_details()['runId']
    child_run = Run.get(ws, child_runid)
    
    child_details = child_run.get_details()
    sequence_id = child_details['runDefinition']['arguments'][-1]
    
    child_run.download_files(prefix = 'outputs/predicted_structures', output_directory = f'./results/{sequence_id}', append_prefix = False)

# %% [markdown]
# Render PDBs

# %%
## Install py3Dmol
# import sys
# !{sys.executable} -m pip install py3Dmol

import py3Dmol

## Get dict of PDB files
pdbs = {}

for path, folder, files in os.walk('./results'):
    for name in files:
        if name.endswith('.pdb'):
            pdbs[name] = f'{path}/{name}'
pdbs## Install py3Dmol
# import sys
# !{sys.executable} -m pip install py3Dmol

import py3Dmol

## Get dict of PDB files
pdbs = {}

for path, folder, files in os.walk('./results'):
    for name in files:
        if name.endswith('.pdb'):
            pdbs[name] = f'{path}/{name}'
# pdbs

###################
from ipywidgets import interact,fixed,IntSlider
import ipywidgets

## Make interactive PDB viewer
def view_pdb(path, style):
    view = py3Dmol.view(js='https://3dmol.org/build/3Dmol.js', width=800, height=800)
    view.addModel(open(path,'r').read(),'pdb')
    view.setStyle({style: {'colorscheme': {'prop':'b','gradient': 'roygb','min':50,'max':90}}})
    view.zoomTo()
    return view

def pdb_viewer(structure, style):
    pdb_path = pdbs[structure]
    return view_pdb(pdb_path, style).show()

interact(pdb_viewer,
         structure=ipywidgets.Dropdown(
            options=pdbs.keys(),
            description='Structure:'),
         style=ipywidgets.Dropdown(
             options = ['line', 'stick', 'sphere', 'cartoon'],
             value='cartoon',
             description='Style:')
        )
# Out:
# interactive(children=(Dropdown(description='Structure:', options=('delta_b1617_7v70_unrelaxed_rank_1_model_1.p…
# <function __main__.pdb_viewer(structure, style)>

# %% [markdown]
# Thank's!
